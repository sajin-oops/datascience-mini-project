# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('D:\\PPT FOR MINI PROJECT/Blank QuizFinal.csv')
df
# Out:
#               Timestamp                   Email Address  Score  \
# 0    9/24/2024 20:00:41           424ds00641@mcc.edu.in    NaN
# 1    9/24/2024 20:22:20  bsccs.222107020@alphagroup.edu    NaN
# 2    9/24/2024 20:36:32       arivazhagan729s@gmail.com    NaN
# 3     9/25/2024 9:50:01                             NaN    NaN
# 4    9/26/2024 12:31:40                             NaN    NaN
# 5    9/26/2024 14:40:59                             NaN    NaN
# 6    9/26/2024 14:48:58                             NaN    NaN
# 7    9/26/2024 19:25:59                             NaN    NaN
# 8    9/26/2024 19:34:17                             NaN    NaN
# 9    9/26/2024 23:57:11                             NaN    NaN
# 10   10/8/2024 20:26:31                             NaN    NaN
# 11   10/8/2024 20:54:12                             NaN    NaN
# 12   10/8/2024 21:08:44                             NaN    NaN
# 13   10/8/2024 22:55:10                             NaN    NaN
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               Timestamp                   Email Address  Score  \
# 0    9/24/2024 20:00:41           424ds00641@mcc.edu.in    NaN
# 1    9/24/2024 20:22:20  bsccs.222107020@alphagroup.edu    NaN
# 2    9/24/2024 20:36:32       arivazhagan729s@gmail.com    NaN
# 3     9/25/2024 9:50:01                             NaN    NaN
# 4    9/26/2024 12:31:40                             NaN    NaN
# 5    9/26/2024 14:40:59                             NaN    NaN
# 6    9/26/2024 14:48:58                             NaN    NaN
# 7    9/26/2024 19:25:59                             NaN    NaN
# 8    9/26/2024 19:34:17                             NaN    NaN
# 9    9/26/2024 23:57:11                             NaN    NaN
# 10   10/8/2024 20:26:31                             NaN    NaN
# 11   10/8/2024 20:54:12                             NaN    NaN
# 12   10/8/2024 21:08:44                             NaN    NaN
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: [Timestamp, Email Address, Score, Name , Gender, How familiar are you with artificial intelligence?   , How do you think AI will impact the job market in the next 10 years?  ,   Do you believe AI can make ethical decisions?  , What is your biggest hope or fear regarding the future of AI?  , Any additional thoughts on the impact of AI on society?  , How do you feel about the use of AI in daily life?   , What sources do you rely on to learn about AI?   , What do you think is the biggest challenge AI will face in the next decade?  , Have you heard of artificial intelligence before?  ,   Do you think AI is helpful?  , Have you ever used a voice assistant like Siri or Alexa?   ]
# Index: []

# %%
df_clean = df.drop('Email Address', axis = 1)
df.drop('Email Address', axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Score', 'Name ', 'Gender',
#        'How familiar are you with artificial intelligence?   ',
#        'How do you think AI will impact the job market in the next 10 years?  ',
#        '  Do you believe AI can make ethical decisions?  ',
#        'What is your biggest hope or fear regarding the future of AI?  ',
#        'Any additional thoughts on the impact of AI on society?  ',
#        'How do you feel about the use of AI in daily life?   ',
#        'What sources do you rely on to learn about AI?   ',
#        'What do you think is the biggest challenge AI will face in the next decade?  ',
#        'Have you heard of artificial intelligence before?  ',
#        '  Do you think AI is helpful?  ',
#        'Have you ever used a voice assistant like Siri or Alexa?   '],
#       dtype='object')

# %%
df
# Out:
#               Timestamp  Score                 Name   Gender  \
# 0    9/24/2024 20:00:41    NaN             SAJIN A.K    Male
# 1    9/24/2024 20:22:20    NaN             SAJIN A.K    Male
# 2    9/24/2024 20:36:32    NaN        Arivazhagan S     Male
# 3     9/25/2024 9:50:01    NaN           Benin Jaswa    Male
# 4    9/26/2024 12:31:40    NaN               Blessy   Female
# 5    9/26/2024 14:40:59    NaN                  arul    Male
# 6    9/26/2024 14:48:58    NaN                 Ahiya  Female
# 7    9/26/2024 19:25:59    NaN       Oliviya princy   Female
# 8    9/26/2024 19:34:17    NaN               Esther   Female
# 9    9/26/2024 23:57:11    NaN               ROSHAN     Male
# 10   10/8/2024 20:26:31    NaN          Benin Jaswa     Male
# 11   10/8/2024 20:54:12    NaN                  Arul    Male
# 12   10/8/2024 21:08:44    NaN                Vinaya  Female
# 13   10/8/2024 22:55:10    NaN                  Ancy  Female
# ...

# %%
df.head()
# Out:
#             Timestamp  Score           Name   Gender  \
# 0  9/24/2024 20:00:41    NaN       SAJIN A.K    Male
# 1  9/24/2024 20:22:20    NaN       SAJIN A.K    Male
# 2  9/24/2024 20:36:32    NaN  Arivazhagan S     Male
# 3   9/25/2024 9:50:01    NaN     Benin Jaswa    Male
# 4  9/26/2024 12:31:40    NaN         Blessy   Female
#
#   How familiar are you with artificial intelligence?     \
# 0                                  Somewhat familiar
# 1                                       Not familiar
# 2                                  Somewhat familiar
# 3                                  Somewhat familiar
# 4                                  Somewhat familiar
#
#   How do you think AI will impact the job market in the next 10 years?    \
# 0                               Not sure about that
# 1                                            No idea
# 2                                   No idea about it
# 3                                     very dangerous
# ...

# %%
df.tail()
# Out:
#               Timestamp  Score    Name  Gender  \
# 28  10/14/2024 10:13:05    NaN   wesley   Male
# 29  10/14/2024 10:14:42    NaN     guna   Male
# 30  10/14/2024 10:15:08    NaN  dhinash   Male
# 31  10/14/2024 10:15:30    NaN     dina   Male
# 32  10/14/2024 10:16:02    NaN   ganesh   Male
#
#    How familiar are you with artificial intelligence?     \
# 28                                       Not familiar
# 29                                       Not familiar
# 30                                       Not familiar
# 31                                       Not familiar
# 32                                       Not familiar
#
#    How do you think AI will impact the job market in the next 10 years?    \
# 28                                                  -
# 29                                                  -
# 30                                                  -
# 31                                                  -
# ...

# %%
df.info() #used to check all the datatypes and the datavalues like column values and row values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 15 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Timestamp                                                                      33 non-null     object
#  1   Score                                                                          0 non-null      float64
#  2   Name                                                                           33 non-null     object
#  3   Gender                                                                         33 non-null     object
#  4   How familiar are you with artificial intelligence?                             33 non-null     object
#  5   How do you think AI will impact the job market in the next 10 years?           33 non-null     object
# ...

# %%
df.isnull()
# Out:
#     Timestamp  Score  Name   Gender  \
# 0       False   True  False   False
# 1       False   True  False   False
# 2       False   True  False   False
# 3       False   True  False   False
# 4       False   True  False   False
# 5       False   True  False   False
# 6       False   True  False   False
# 7       False   True  False   False
# 8       False   True  False   False
# 9       False   True  False   False
# 10      False   True  False   False
# 11      False   True  False   False
# 12      False   True  False   False
# 13      False   True  False   False
# 14      False   True  False   False
# 15      False   True  False   False
# 16      False   True  False   False
# 17      False   True  False   False
# 18      False   True  False   False
# 19      False   True  False   False
# 20      False   True  False   False
# 21      False   True  False   False
# 22      False   True  False   False
# 23      False   True  False   False
# 24      False   True  False   False
# ...

# %%
df.drop('Score', axis=1, inplace=True)
print(df)
# Out:
#               Timestamp                 Name   Gender  \
# 0    9/24/2024 20:00:41             SAJIN A.K    Male
# 1    9/24/2024 20:22:20             SAJIN A.K    Male
# 2    9/24/2024 20:36:32        Arivazhagan S     Male
# 3     9/25/2024 9:50:01           Benin Jaswa    Male
# 4    9/26/2024 12:31:40               Blessy   Female
# 5    9/26/2024 14:40:59                  arul    Male
# 6    9/26/2024 14:48:58                 Ahiya  Female
# 7    9/26/2024 19:25:59       Oliviya princy   Female
# 8    9/26/2024 19:34:17               Esther   Female
# 9    9/26/2024 23:57:11               ROSHAN     Male
# 10   10/8/2024 20:26:31          Benin Jaswa     Male
# 11   10/8/2024 20:54:12                  Arul    Male
# 12   10/8/2024 21:08:44                Vinaya  Female
# 13   10/8/2024 22:55:10                  Ancy  Female
# 14  10/13/2024 14:45:46            Keerthana   Female
# 15  10/13/2024 14:48:34  Raphel Panneerselvam    Male
# ...

# %%
df.head()
# Out:
#             Timestamp           Name   Gender  \
# 0  9/24/2024 20:00:41       SAJIN A.K    Male
# 1  9/24/2024 20:22:20       SAJIN A.K    Male
# 2  9/24/2024 20:36:32  Arivazhagan S     Male
# 3   9/25/2024 9:50:01     Benin Jaswa    Male
# 4  9/26/2024 12:31:40         Blessy   Female
#
#   How familiar are you with artificial intelligence?     \
# 0                                  Somewhat familiar
# 1                                       Not familiar
# 2                                  Somewhat familiar
# 3                                  Somewhat familiar
# 4                                  Somewhat familiar
#
#   How do you think AI will impact the job market in the next 10 years?    \
# 0                               Not sure about that
# 1                                            No idea
# 2                                   No idea about it
# 3                                     very dangerous
# 4                                               Yep!
#
# ...

# %%
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 2})
print(df)
# Out:
#               Timestamp                 Name   Gender  \
# 0    9/24/2024 20:00:41             SAJIN A.K       1
# 1    9/24/2024 20:22:20             SAJIN A.K       1
# 2    9/24/2024 20:36:32        Arivazhagan S        1
# 3     9/25/2024 9:50:01           Benin Jaswa       1
# 4    9/26/2024 12:31:40               Blessy        2
# 5    9/26/2024 14:40:59                  arul       1
# 6    9/26/2024 14:48:58                 Ahiya       2
# 7    9/26/2024 19:25:59       Oliviya princy        2
# 8    9/26/2024 19:34:17               Esther        2
# 9    9/26/2024 23:57:11               ROSHAN        1
# 10   10/8/2024 20:26:31          Benin Jaswa        1
# 11   10/8/2024 20:54:12                  Arul       1
# 12   10/8/2024 21:08:44                Vinaya       2
# 13   10/8/2024 22:55:10                  Ancy       2
# 14  10/13/2024 14:45:46            Keerthana        2
# 15  10/13/2024 14:48:34  Raphel Panneerselvam       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 14 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Timestamp                                                                      33 non-null     object
#  1   Name                                                                           33 non-null     object
#  2   Gender                                                                         33 non-null     object
#  3   How familiar are you with artificial intelligence?                             33 non-null     object
#  4   How do you think AI will impact the job market in the next 10 years?           33 non-null     object
#  5     Do you believe AI can make ethical decisions?                                33 non-null     object
# ...

# %%
print(df.columns)
# Out:
# Index(['Timestamp', 'Name ', 'Gender',
#        'How familiar are you with artificial intelligence?   ',
#        'How do you think AI will impact the job market in the next 10 years?  ',
#        '  Do you believe AI can make ethical decisions?  ',
#        'What is your biggest hope or fear regarding the future of AI?  ',
#        'Any additional thoughts on the impact of AI on society?  ',
#        'How do you feel about the use of AI in daily life?   ',
#        'What sources do you rely on to learn about AI?   ',
#        'What do you think is the biggest challenge AI will face in the next decade?  ',
#        'Have you heard of artificial intelligence before?  ',
#        '  Do you think AI is helpful?  ',
#        'Have you ever used a voice assistant like Siri or Alexa?   '],
#       dtype='object')

# %%
# Strip whitespace from all column names
df.columns = df.columns.str.strip()

# Now try the countplot again
import seaborn as sns
import matplotlib.pyplot as plt

# Create the countplot
sns.countplot(data=df, x='How familiar are you with artificial intelligence?', hue='How do you think AI will impact the job market in the next 10 years?')
plt.xticks(rotation=45)
plt.show()
